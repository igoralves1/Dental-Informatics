# %% [markdown]
# <a href="https://colab.research.google.com/github/igoralves1/Dental-Informatics/blob/main/Python-Course/Colaboratory/Data_Mining_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is a course of data managemt for Health Professionals
#
# References:
#
#
# 1.   [Python Pandas Tutorial](https://www.tutorialspoint.com/python_pandas/index.htm)
# 2.   [Nbviewer](https://nbviewer.jupyter.org/)

# %% [markdown]
# # **Import CSV file from GitHub repository**
# This is the [link](https://raw.githubusercontent.com/igoralves1/scrap2019-ncov/master/1581352943315.csv) to the repository

# %%
import pandas as pd
df_csv=pd.read_csv('https://raw.githubusercontent.com/igoralves1/scrap2019-ncov/master/1581352943315.csv')
df_csv.tail()

# %% [markdown]
# # **Import JSON file from GitHub repository**
# This is the [link](https://raw.githubusercontent.com/igoralves1/Dental-Informatics/main/Python-Course/data/example1.json) to the repository

# %%
# Example 1
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}
df_json = pd.DataFrame(data)
print(df_json)

# %%
# Example 2
data = pd.read_json('https://raw.githubusercontent.com/igoralves1/Dental-Informatics/main/Python-Course/data/example1.json')
df_json = pd.DataFrame(data)
print(df_json)
